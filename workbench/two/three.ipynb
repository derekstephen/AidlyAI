# %%
# Usual imports
import numpy as np
import pandas as pd
from tqdm import tqdm
import string
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import concurrent.futures
import time
import pyLDAvis.sklearn
from pylab import bone, pcolor, colorbar, plot, show, rcParams, savefig
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import os
'''
# Plotly based imports for visualization
from plotly import tools
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
'''
# spaCy based imports
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
# !python -m spacy download en_core_web_lg
# Out:
# Requirement already satisfied: en_core_web_lg==2.3.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.0/en_core_web_lg-2.3.0.tar.gz#egg=en_core_web_lg==2.3.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (2.3.0)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from en_core_web_lg==2.3.0) (2.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (2.0.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (4.47.0)
# Requirement already satisfied: setuptools in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (41.2.0)
# Requirement already satisfied: thinc==7.4.1 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (7.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (1.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (2.24.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (1.19.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (3.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (1.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ddeto\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_lg==2.3.0) (1.25.9)
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
ngos = pd.read_csv('C:\\Users\\ddeto\\PycharmProjects\\AidlyAI\\Data\\MISSION_CLEAN.csv')
ngos.head()
# Out:
#         EIN                                   NAME  TAXYR  FORMTYPE  \
# 0  10716217  THE SAN FRANCISCO HOUSING ACCELERATOR   2016       990
# 1  10842551           CREEKSIDE ELEMENTARY PTO INC   2015       990
# 2  20792368         COVINGTON COMMUNITY SPORTS INC   2011       990
# 3  43611860            METRO COMMUNITY DEVELOPMENT   2016       990
# 4  43611860            METRO COMMUNITY DEVELOPMENT   2015       990
#
#        OBJECTID                                                URL  \
# 0  2.018110e+17  https://s3.amazonaws.com/irs-form-990/20181135...
# 1  2.016220e+17  https://s3.amazonaws.com/irs-form-990/20162238...
# 2  2.012420e+17  https://s3.amazonaws.com/irs-form-990/20124195...
# 3  2.017130e+17  https://s3.amazonaws.com/irs-form-990/20171318...
# 4  2.016420e+17  https://s3.amazonaws.com/irs-form-990/20164162...
#
#   F9_03_PC_NEW_PROG_CHECKBOX F9_03_PC_SIG_CHANGE_CHECKBOX  \
# 0                          0                            0
# 1                      FALSE                        FALSE
# 2                      FALSE                        FALSE
# 3                          0                            0
# 4                          0                            0
#
#    F9_03_PC_TOTAL_PROG_EXP                                   F9_03_PZ_MISSION  \
# 0                 401061.0  THE CORPORATION'S SPECIFIC PURPOSE IS TO SUPPO...
# 1                      NaN      SUPPORT HARTLAND CREEKSIDE ELEMENTARY SCHOOL.
# 2                 182141.0                         COMMUNITY SPORTS PROGRAMS.
# 3                 139435.0  TO RELIEVE THE POOR, THE DISTRESSED AND THE UN...
# 4                 165035.0  TO RELIEVE THE POOR, THE DISTRESSED AND THE UN...
#
#    ... Onethirdsupportgifts Benefitofcollege  Privatefoundation508e  \
# 0  ...                    1                0                      0
# 1  ...                    0                0                      0
# 2  ...                    1                0                      0
# 3  ...                    0                0                      0
# 4  ...                    0                0                      0
#
#    Seekingretroreinstatement Seekingsec7reinstatement Correctnessdeclaration  \
# 0                          1                        0                      1
# 1                          1                        0                      1
# 2                          1                        0                      1
# 3                          1                        0                      1
# 4                          1                        0                      1
#
#               Signaturename      Signaturetitle Signaturedate  NTEE
# 0              TERESA YANGA  EXECUTIVE DIRECTOR     7/30/2015     L
# 1                CARA SUKSI           TREASURER     9/23/2015     B
# 2             SHAWN STEWART      VICE PRESIDENT      9/6/2016     N
# 3  DELORES WILKERSON-JACOBS     BOARD PRESIDENT    12/10/2014     N
# 4  DELORES WILKERSON-JACOBS     BOARD PRESIDENT    12/10/2014     N
#
# [5 rows x 115 columns]

# %%
import texthero as hero

ngos['pca'] = (
   ngos['F9_03_PZ_MISSION']
   .pipe(hero.clean)
   .pipe(hero.tfidf)
   .pipe(hero.pca)
)

ngos['clean'] = (
   ngos['F9_03_PZ_MISSION']
   .pipe(hero.clean)
)

ngos['tfidf'] = (
   ngos['F9_03_PZ_MISSION']
   .pipe(hero.clean)
   .pipe(hero.tfidf)
)

ngos['kmeans_labels'] = (
    ngos['tfidf']
    .pipe(hero.kmeans, n_clusters=5)
    .astype(str)
)

ngos['tokenize'] = (
    ngos['F9_03_PZ_MISSION']
    .pipe(hero.fillna)
    .pipe(hero.lowercase)
    .pipe(hero.remove_punctuation)
    .pipe(hero.remove_whitespace)
    .pipe(hero.tokenize)
)

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\ddeto\\PycharmProjects\\AidlyAI\\Data\\berks_NGOs.csv')
corpus_text = '\n'.join(df[:50000]['Mission_Statement'])
sentences = corpus_text.split('\n')
sentences = [line.lower().split(' ') for line in sentences]

def clean(s):
    return [w.strip(',."!?:;()\'') for w in s]
sentences = [clean(s) for s in sentences if len(s) > 0]

# %%
words_from_df = []

for index, row in ngos.iterrows():
    words_from_df.append(row['tokenize'])

words_from_df
# Out:
# [['the',
#   'corporation',
#   's',
#   'specific',
#   'purpose',
#   'is',
#   'to',
#   'supports',
#   'affordable',
#   'housing',
#   'community',
#   'development',
#   'and',
#   'economic',
#   'development',
#   'of',
#   'the',
#   'city',
#   'and',
#   'county',
#   'of',
#   'san',
#   'francisco',
#   's',
#   'economically',
#   'disadvantaged',
#   'individuals',
#   'and',
#   'communities',
#   'by',
#   'lending',
#   'to',
#   'investing',
#   'in',
#   'and',
#   'directly',
#   'acquiring',
#   'such',
#   'affordable',
#   'housing',
#   'and',
#   'related',
#   'community',
#   'development',
#   'real',
#   'estate',
#   'assets'],
#  ['support', 'hartland', 'creekside', 'elementary', 'school'],
#  ['community', 'sports', 'programs'],
#  ['to',
#   'relieve',
#   'the',
#   'poor',
#   'the',
#   'distressed',
#   'and',
#   'the',
#   'underprivilaged',
#   'and',
#   'combat',
#   'community',
#   'deterioration',
#   'in',
#   'the',
#   'buffalo',
#   'niagara',
#   'region',
#   'of',
#   'new',
#   'york',
#   'state',
#   'by',
#   'establishing',
#   'and',
#   'maintaining',
#   'a',
#   'faith',
#   'based',
#   'community',
#   'development',
#   'corporation'],
#  ['to',
#   'relieve',
#   'the',
#   'poor',
#   'the',
#   'distressed',
#   'and',
#   'the',
#   'underprivilaged',
#   'and',
#   'combat',
#   'community',
#   'deterioration',
#   'in',
#   'the',
#   'buffalo',
#   'niagara',
#   'region',
#   'of',
#   'new',
#   'york',
#   'state',
#   'by',
#   'establishing',
#   'and',
#   'maintaining',
#   'a',
#   'faith',
#   'based',
#   'community',
#   'development',
#   'corporation'],
#  ['family',
#   'gateway',
#   'affordable',
#   'housing',
#   'inc',
#   'fgah',
#   'is',
#   'operated',
#   'supervised',
#   'and',
#   'controlled',
#   'by',
#   'family',
#   'gateway',
#   'inc',
#   'fg',
#   'a',
#   'texas',
#   'nonprofit',
#   'for',
#   'the',
#   'purpose',
#   'of',
#   'building',
#   'and',
#   'operating',
#   'housing',
#   'units',
#   'available',
#   'to',
#   'low',
#   'income',
#   'tenants',
#   'fgah',
#   'works',
#   'with',
#   'fg',
#   'to',
#   'provide',
#   'various',
#   'support',
#   'services',
#   'to',
#   'tenants',
#   'occupying',
#   'fgah',
#   's',
#   'property',
#   'and',
#   'assist',
#   'fg',
#   'in',
#   'fulfillling',
#   'its',
#   'purposes',
#   'of',
#   'providing',
#   'safe',
#   'decent',
#   'and',
#   'affordable',
#   'housing',
#   'to',
#   'low',
#   'income',
#   'and',
#   'very',
#   'low',
#   'income',
#   'individuals'],
#  ['youth', 'ministry', 'adult', 'ministry'],
#  ['assistance', 'with', 'medical', 'and', 'education', 'expenses'],
#  ['we',
#   'are',
#   'a',
#   'grass',
#   'roots',
#   'volunteer',
#   'based',
#   'sephardic',
#   'synagogue',
#   'founded',
#   'by',
#   'a',
#   'group',
#   'of',
#   'dedicated',
#   'jewish',
#   'professionals',
#   'who',
#   'are',
#   'devoted',
#   'to',
#   'maintaining',
#   'ties',
#   'to',
#   'their',
#   'history',
#   'and',
#   'tradition',
#   'while',
#   'developing',
#   'leadership',
#   'and',
#   'growth'],
#  ['we',
#   'are',
#   'a',
#   'grass',
#   'roots',
#   'volunteer',
#   'based',
#   'sephardic',
#   'synagogue',
#   'founded',
#   'by',
#   'a',
#   'group',
#   'of',
#   'dedicated',
#   'jewish',
#   'professionals',
#   'who',
#   'are',
#   'devoted',
#   'to',
#   'maintaining',
#   'ties',
#   'to',
#   'their',
#   'history',
#   'and',
#   'tradition',
#   'while',
#   'developing',
#   'leadership',
#   'and',
#   'growth'],
#  ['we',
#   'are',
#   'a',
#   'grass',
#   'roots',
#   'volunteer',
#   'based',
#   'sephardic',
#   'synagogue',
#   'founded',
#   'by',
#   'a',
#   'group',
#   'of',
#   'dedicated',
#   'jewish',
#   'professionals',
#   'who',
#   'are',
#   'devoted',
#   'to',
#   'maintaining',
#   'ties',
#   'to',
#   'their',
#   'history',
#   'and',
#   'tradition',
#   'while',
#   'developing',
#   'leadership',
#   'and',
#   'growth'],
#  ['to',
#   'promote',
#   'and',
#   'recognize',
#   'the',
#   'practice',
#   'of',
#   'law',
#   'by',
#   'asian',
#   'pacific',
#   'men',
#   'and',
#   'women',
#   'in',
#   'the',
#   'state',
#   'of',
#   'connecticut'],
#  ['provides',
#   'shelter',
#   'medical',
#   'care',
#   'and',
#   'food',
#   'to',
#   'stray',
#   'unwanted',
#   'dogs'],
#  ['im',
#   'still',
#   'standing',
#   'by',
#   'grace',
#   'is',
#   'a',
#   'regional',
#   'behavioral',
#   'healthcare',
#   'and',
#   'certified',
#   'substance',
#   'abuse',
#   'system',
#   'that',
#   'provides',
#   'comprehensive',
#   'and',
#   'caring',
#   'services',
#   'to',
#   'adults',
#   'and',
#   'their',
#   'families'],
#  ['im',
#   'still',
#   'standing',
#   'by',
#   'grace',
#   'is',
#   'a',
#   'regional',
#   'behavioral',
#   'healthcare',
#   'and',
#   'certified',
#   'substance',
#   'abuse',
#   'system',
#   'that',
#   'provides',
#   'comprehensive',
#   'and',
#   'caring',
#   'services',
#   'to',
#   'adults',
#   'and',
#   'their',
#   'families'],
#  ['im',
#   'still',
#   'standing',
#   'by',
#   'grace',
#   'is',
#   'a',
#   'regional',
#   'behavioral',
#   'healthcare',
#   'and',
#   'certified',
#   'substance',
#   'abuse',
#   'system',
#   'that',
#   'provides',
#   'comprehensive',
#   'and',
#   'caring',
#   'services',
#   'to',
#   'adults',
#   'and',
#   'their',
#   'families'],
#  ['supports',
#   'community',
#   'charities',
#   'through',
#   'awards',
#   'scholarships',
#   'grants',
#   'and',
#   'donations'],
#  ['supports',
#   'community',
#   'charities',
#   'through',
#   'awards',
#   'scholarships',
#   'grants',
#   'and',
#   'donations'],
#  ['supports',
#   'community',
#   'charities',
#   'through',
#   'awards',
#   'scholarships',
#   'grants',
#   'and',
#   'donations'],
#  ['charitable', 'organization'],
#  ['charitable', 'organization'],
#  ['charitable', 'organization'],
#  ['a',
#   'program',
#   'to',
#   'provide',
#   'therapeutic',
#   'services',
#   'to',
#   'the',
#   'families',
#   'of',
#   'kiryat',
#   'hebron',
#   'and',
#   'surrounding',
#   'areas',
#   'in',
#   'isreal'],
#  ['youth', 'development', 'programs'],
#  ['youth', 'development', 'programs'],
#  ['youth', 'development', 'programs'],
#  ['youth', 'development', 'programs'],
#  ['promote', 'education', 'of', 'human', 'life'],
#  ['promote', 'education', 'of', 'human', 'life'],
#  ['provide',
#   'a',
#   'recreational',
#   'soccer',
#   'program',
#   'for',
#   'children',
#   'of',
#   'residents',
#   'in'],
#  ['provide', 'a', 'recreational', 'soccer'],
#  ['commercial', 'development'],
#  ['commercial', 'development'],
#  ['just',
#   'play',
#   'soccer',
#   'club',
#   'inc',
#   'is',
#   'a',
#   'non',
#   'for',
#   'profit',
#   'organization',
#   'under',
#   'irc',
#   '501c',
#   '3',
#   'the',
#   'corporation',
#   'exists',
#   'as',
#   'a',
#   'result',
#   'of',
#   'a',
#   'compelling',
#   'demand',
#   'by',
#   'the',
#   'westchester',
#   'youth',
#   'soccer',
#   'league',
#   'that',
#   'all',
#   'participating',
#   'clubs',
#   'be',
#   'legally',
#   'designated',
#   'as',
#   'non',
#   'for',
#   'profit',
#   'organizations',
#   'we',
#   'are',
#   'a',
#   'group',
#   'of',
#   'parents',
#   'who',
#   'seek',
#   'high',
#   'quality',
#   'soccer',
#   'opportunities',
#   'for',
#   'our',
#   'children',
#   'to',
#   'meet',
#   'this',
#   'goal',
#   'we',
#   'have',
#   'established',
#   'a',
#   'relationship',
#   'with',
#   'the',
#   'westchester',
#   'youth',
#   'soccer',
#   'governing',
#   'body'],
#  ['to',
#   'educate',
#   'and',
#   'empower',
#   'young',
#   'people',
#   'to',
#   'make',
#   'healthy',
#   'life',
#   'choices'],
#  ['publication', 'of', 'new', 'leader', 'magazine'],
#  ['publication', 'of', 'new', 'leader', 'magazine'],
#  ['the',
#   'horological',
#   'society',
#   'of',
#   'new',
#   'york',
#   'is',
#   'dedicated',
#   'to',
#   'advancing',
#   'the',
#   'art',
#   'and',
#   'science',
#   'of',
#   'horology',
#   'members',
#   'are',
#   'a',
#   'diverse',
#   'mix',
#   'of',
#   'watchmakers',
#   'clockmakers',
#   'executives',
#   'journalists',
#   'auctioneers',
#   'historians',
#   'salespeople',
#   'and',
#   'collectors',
#   'reflecting',
#   'the',
#   'rich',
#   'nature',
#   'of',
#   'horology',
#   'in',
#   'new',
#   'york',
#   'city'],
#  ['the',
#   'horological',
#   'society',
#   'of',
#   'new',
#   'york',
#   'is',
#   'dedicated',
#   'to',
#   'advancing',
#   'the',
#   'art',
#   'and',
#   'science',
#   'of',
#   'horology',
#   'members',
#   'are',
#   'a',
#   'diverse',
#   'mix',
#   'of',
#   'watchmakers',
#   'clockmakers',
#   'executives',
#   'journalists',
#   'auctioneers',
#   'historians',
#   'salespeople',
#   'and',
#   'collectors',
#   'reflecting',
#   'the',
#   'rich',
#   'nature',
#   'of',
#   'horology',
#   'in',
#   'new',
#   'york',
#   'city'],
#  ['to',
#   'provide',
#   'exclusively',
#   'for',
#   'charitable',
#   'and',
#   'educational',
#   'purposes',
#   'a',
#   'center',
#   'which',
#   'will',
#   'provide',
#   'multimedia',
#   'equipment',
#   'technologies',
#   'and',
#   'or',
#   'workshops',
#   'to',
#   'individuals',
#   'and',
#   'groups',
#   'to',
#   'produce',
#   'media',
#   'for',
#   'artistic'],
#  ['to',
#   'provide',
#   'exclusively',
#   'for',
#   'charitable',
#   'and',
#   'educational',
#   'purposes',
#   'a',
#   'center',
#   'wjich',
#   'will',
#   'provide',
#   'multimedia',
#   'equipment',
#   'technologies',
#   'and',
#   'or',
#   'workshops',
#   'to',
#   'individuals',
#   'and',
#   'groups',
#   'to',
#   'produce',
#   'media',
#   'for',
#   'artistic'],
#  ['firefighting'],
#  ['firefighting'],
#  ['to', 'provide', 'emergency', 'medical', 'transportation'],
#  ['to', 'provide', 'emergency', 'medical', 'transportation'],
#  ['to', 'provide', 'emergency', 'medical', 'transportation'],
#  ['to', 'provide', 'emergency', 'medical', 'transportation'],
#  ['mental',
#   'health',
#   'america',
#   'of',
#   'monroe',
#   'county',
#   'is',
#   'a',
#   '501',
#   'c',
#   '3',
#   'nonprofit',
#   'organization',
#   'dedicated',
#   'to',
#   'promoting',
#   'mental',
#   'health',
#   'and',
#   'supporting',
#   'mental',
#   'health',
#   'consumers',
#   'and',
#   'their',
#   'families',
#   'through',
#   'education',
#   'referral',
#   'and',
#   'service',
#   'we',
#   'achieve',
#   'our',
#   'mission',
#   'by',
#   'educating',
#   'the',
#   'public',
#   'about',
#   'ways',
#   'to',
#   'preserve',
#   'and',
#   'strengthen',
#   'mental',
#   'health',
#   'by',
#   'sponsoring',
#   'support',
#   'groups',
#   'by',
#   'serving',
#   'as',
#   'a',
#   'clearinghouse',
#   'for',
#   'information',
#   'about',
#   'mental',
#   'health',
#   'promotion',
#   'prevention',
#   'and',
#   'treatment',
#   'resources',
#   'in',
#   'our',
#   'community',
#   'and',
#   'by',
#   'fostering',
#   'innovation',
#   'in',
#   'policy',
#   'research',
#   'practice',
#   'and',
#   'services'],
#  ['mental',
#   'health',
#   'america',
#   'of',
#   'monroe',
#   'county',
#   'is',
#   'a',
#   '501',
#   'c',
#   '3',
#   'nonprofit',
#   'organization',
#   'dedicated',
#   'to',
#   'promoting',
#   'mental',
#   'health',
#   'and',
#   'supporting',
#   'mental',
#   'health',
#   'consumers',
#   'and',
#   'their',
#   'families',
#   'through',
#   'education',
#   'referral',
#   'and',
#   'service',
#   'we',
#   'achieve',
#   'our',
#   'mission',
#   'by',
#   'educating',
#   'the',
#   'public',
#   'about',
#   'ways',
#   'to',
#   'preserve',
#   'and',
#   'strengthen',
#   'mental',
#   'health',
#   'by',
#   'sponsoring',
#   'support',
#   'groups',
#   'by',
#   'serving',
#   'as',
#   'a',
#   'clearinghouse',
#   'for',
#   'information',
#   'about',
#   'mental',
#   'health',
#   'promotion',
#   'prevention',
#   'and',
#   'treatment',
#   'resources',
#   'in',
#   'our',
#   'community',
#   'and',
#   'by',
#   'fostering',
#   'innovation',
#   'in',
#   'policy',
#   'research',
#   'practice',
#   'and',
#   'services'],
#  ['mental',
#   'health',
#   'america',
#   'of',
#   'monroe',
#   'county',
#   'is',
#   'a',
#   '501',
#   'c',
#   '3',
#   'nonprofit',
#   'organization',
#   'dedicated',
#   'to',
#   'promoting',
#   'mental',
#   'health',
#   'and',
#   'supporting',
#   'mental',
#   'health',
#   'consumers',
#   'and',
#   'their',
#   'families',
#   'through',
#   'education',
#   'referral',
#   'and',
#   'service',
#   'we',
#   'achieve',
#   'our',
#   'mission',
#   'by',
#   'educating',
#   'the',
#   'public',
#   'about',
#   'ways',
#   'to',
#   'preserve',
#   'and',
#   'strengthen',
#   'mental',
#   'health',
#   'by',
#   'sponsoring',
#   'support',
#   'groups',
#   'by',
#   'serving',
#   'as',
#   'a',
#   'clearinghouse',
#   'for',
#   'information',
#   'about',
#   'mental',
#   'health',
#   'promotion',
#   'prevention',
#   'and',
#   'treatment',
#   'resources',
#   'in',
#   'our',
#   'community',
#   'and',
#   'by',
#   'fostering',
#   'innovation',
#   'in',
#   'policy',
#   'research',
#   'practice',
#   'and',
#   'services'],
#  ['mental',
#   'health',
#   'america',
#   'of',
#   'monroe',
#   'county',
#   'is',
#   'a',
#   '501',
#   'c',
#   '3',
#   'nonprofit',
#   'organization',
#   'dedicated',
#   'to',
#   'promoting',
#   'mental',
#   'health',
#   'and',
#   'supporting',
#   'mental',
#   'health',
#   'consumers',
#   'and',
#   'their',
#   'families',
#   'through',
#   'education',
#   'referral',
#   'and',
#   'service',
#   'we',
#   'achieve',
#   'our',
#   'mission',
#   'by',
#   'educating',
#   'the',
#   'public',
#   'about',
#   'ways',
#   'to',
#   'preserve',
#   'and',
#   'strengthen',
#   'mental',
#   'health',
#   'by',
#   'sponsoring',
#   'support',
#   'groups',
#   'by',
#   'serving',
#   'as',
#   'a',
#   'clearinghouse',
#   'for',
#   'information',
#   'about',
#   'mental',
#   'health',
#   'promotion',
#   'prevention',
#   'and',
#   'treatment',
#   'resources',
#   'in',
#   'our',
#   'community',
#   'and',
#   'by',
#   'fostering',
#   'innovation',
#   'in',
#   'policy',
#   'research',
#   'practice',
#   'and',
#   'services'],
#  ['supported',
#   'living',
#   'coaching',
#   'companion',
#   'non',
#   'residential',
#   'support',
#   'in',
#   'home',
#   'support',
#   'and',
#   'trasnsportation',
#   'provided',
#   'for',
#   'developmentally',
#   'disabled',
#   'foster',
#   'care',
#   'aged',
#   'and',
#   'adult',
#   'services'],
#  ['to',
#   'educate',
#   'health',
#   'care',
#   'professionals',
#   'on',
#   'the',
#   'developments',
#   'concerning',
#   'advances',
#   'in',
#   'health',
#   'care'],
#  ['volunteer', 'fire', 'department'],
#  ['volunteer', 'fire', 'department'],
#  ['volunteer', 'fire', 'department'],
#  ['to',
#   'provide',
#   'affordable',
#   'home',
#   'ownership',
#   'to',
#   'low',
#   'and',
#   'moderate',
#   'income',
#   'families',
#   'thru',
#   'construction',
#   'and',
#   'rehabilitation'],
#  ['provide',
#   'a',
#   'museum',
#   'of',
#   'local',
#   'railroad',
#   'history',
#   'for',
#   'educational',
#   'and',
#   'historical',
#   'purposes'],
#  ['the',
#   'organization',
#   'operates',
#   'an',
#   'elementary',
#   'school',
#   'pre',
#   'kindergarten',
#   'through',
#   '5th',
#   'grade',
#   'and',
#   'a',
#   'middle',
#   'school',
#   'grades',
#   '6th',
#   'through',
#   '8th',
#   'curriculum',
#   'emphasizes',
#   'multiple',
#   'teaching',
#   'strategies',
#   'in',
#   'a',
#   'loving',
#   'and',
#   'caring',
#   'environment'],
#  ['america',
#   'at',
#   'work',
#   'is',
#   'the',
#   'premier',
#   'faciliator',
#   'that',
#   'fosters',
#   'the',
#   'economically',
#   'beneficial',
#   'job',
#   'development',
#   'and',
#   'placement',
#   'for',
#   'displaced',
#   'and',
#   'non',
#   'traditional',
#   'workers',
#   'while',
#   'supporting',
#   'a',
#   'fundamental',
#   'shift',
#   'in',
#   'perception',
#   'of',
#   'this',
#   'workfoce',
#   'with',
#   'empoloyers'],
#  ['parent',
#   'organization',
#   'formed',
#   'to',
#   'hold',
#   'fundraising',
#   'activities',
#   'to',
#   'support',
#   'the',
#   'operation',
#   'of',
#   'the',
#   'latchkey',
#   'program',
#   'at',
#   'wellington',
#   'schools'],
#  ['parent',
#   'organization',
#   'formed',
#   'to',
#   'hold',
#   'fundraising',
#   'activities',
#   'to',
#   'support',
#   'the',
#   'operation',
#   'of',
#   'the',
#   'latchkey',
#   'program',
#   'at',
#   'wellington',
#   'schools'],
#  ['parent',
#   'organization',
#   'formed',
#   'to',
#   'hold',
#   'fundraising',
#   'activities',
#   'to',
#   'support',
#   'the',
#   'operation',
#   'of',
#   'the',
#   'latchkey',
#   'program',
#   'at',
#   'wellington',
#   'schools'],
#  ['service', 'to', 'community'],
#  ['service', 'to', 'community'],
#  ['arts', 'culture', 'and', 'humanities'],
#  ['arts', 'culture', 'and', 'humanities'],
#  ['arts', 'culture', 'and', 'humanities'],
#  ['to',
#   'solicit',
#   'donations',
#   'and',
#   'provide',
#   'scholarship',
#   'to',
#   'high',
#   'school',
#   'graduates'],
#  ['we', 'provide', 'homes', 'for', 'children'],
#  ['we', 'provide', 'homes', 'for', 'children'],
#  ['the',
#   'corporation',
#   'is',
#   'formed',
#   'for',
#   'the',
#   'charitable',
#   'purpose',
#   'of',
#   'alleviating',
#   'suffering',
#   'caused',
#   'by',
#   'natural',
#   'disasters',
#   'and',
#   'other',
#   'humanitarian',
#   'crises',
#   'in',
#   'foreign',
#   'countries'],
#  ['to',
#   'restore',
#   'hope',
#   'and',
#   'provide',
#   'opportunities',
#   'for',
#   'people',
#   'to',
#   'become',
#   'all',
#   'that',
#   'god',
#   'intends',
#   'them',
#   'to',
#   'be',
#   'partner',
#   'with',
#   'the',
#   'local',
#   'church',
#   'to',
#   'put',
#   'christian',
#   'faith',
#   'into',
#   'action',
#   'through',
#   'service',
#   'to',
#   'the',
#   'community'],
#  ['to',
#   'restore',
#   'hope',
#   'and',
#   'provide',
#   'opportunities',
#   'for',
#   'people',
#   'to',
#   'become',
#   'all',
#   'that',
#   'god',
#   'intends',
#   'them',
#   'to',
#   'be',
#   'partner',
#   'with',
#   'the',
#   'local',
#   'church',
#   'to',
#   'put',
#   'christian',
#   'faith',
#   'into',
#   'action',
#   'through',
#   'service',
#   'to',
#   'the',
#   'community'],
#  ['to',
#   'restore',
#   'hope',
#   'and',
#   'provide',
#   'opportunities',
#   'for',
#   'people',
#   'to',
#   'become',
#   'all',
#   'that',
#   'god',
#   'intends',
#   'them',
#   'to',
#   'be',
#   'partner',
#   'with',
#   'the',
#   'local',
#   'church',
#   'to',
#   'put',
#   'christian',
#   'faith',
#   'into',
#   'action',
#   'through',
#   'service',
#   'to',
#   'the',
#   'community'],
#  ['improve',
#   'the',
#   'effectiveness',
#   'of',
#   'nutritional',
#   'education',
#   'physical',
#   'education',
#   'social',
#   'and',
#   'emotional',
#   'enhancement',
#   'in',
#   'the',
#   'promotion',
#   'of',
#   'child',
#   'development',
#   'increase',
#   'public',
#   'understanding',
#   'and',
#   'appreciation',
#   'of',
#   'these',
#   'values',
#   'as',
#   'they',
#   'contribute',
#   'to',
#   'child',
#   'development',
#   'evaluate',
#   'professional',
#   'standards',
#   'as',
#   'necessary',
#   'to',
#   'assure',
#   'the',
#   'improvement',
#   'of',
#   'education',
#   'to',
#   'cooperate',
#   'with',
#   'other',
#   'similar',
#   'groups',
#   'within',
#   'the',
#   'region',
#   'having',
#   'common',
#   'interests',
#   'and',
#   'to',
#   'conduct',
#   'activities',
#   'as',
#   'approved',
#   'by',
#   'the',
#   'executive',
#   'board'],
#  ['improve',
#   'the',
#   'effectiveness',
#   'of',
#   'nutritional',
#   'education',
#   'physical',
#   'education',
#   'social',
#   'and',
#   'emotional',
#   'enhancement',
#   'in',
#   'the',
#   'promotion',
#   'of',
#   'child',
#   'development',
#   'increase',
#   'public',
#   'understanding',
#   'and',
#   'appreciation',
#   'of',
#   'these',
#   'values',
#   'as',
#   'they',
#   'contribute',
#   'to',
#   'child',
#   'development',
#   'evaluate',
#   'professional',
#   'standards',
#   'as',
#   'necessary',
#   'to',
#   'assure',
#   'the',
#   'improvement',
#   'of',
#   'education',
#   'to',
#   'cooperate',
#   'with',
#   'other',
#   'similar',
#   'groups',
#   'within',
#   'the',
#   'region',
#   'having',
#   'common',
#   'interests',
#   'and',
#   'to',
#   'conduct',
#   'activities',
#   'as',
#   'approved',
#   'by',
#   'the',
#   'executive',
#   'board'],
#  ['improve',
#   'the',
#   'effectiveness',
#   'of',
#   'nutritional',
#   'education',
#   'physical',
#   'education',
#   'social',
#   'and',
#   'emotional',
#   'enhancement',
#   'in',
#   'the',
#   'promotion',
#   'of',
#   'child',
#   'development',
#   'increase',
#   'public',
#   'understanding',
#   'and',
#   'appreciation',
#   'of',
#   'these',
#   'values',
#   'as',
#   'they',
#   'contribute',
#   'to',
#   'child',
#   'development',
#   'evaluate',
#   'professional',
#   'standards',
#   'as',
#   'necessary',
#   'to',
#   'assure',
#   'the',
#   'improvement',
#   'of',
#   'education',
#   'to',
#   'cooperate',
#   'with',
#   'other',
#   'similar',
#   'groups',
#   'within',
#   'the',
#   'region',
#   'having',
#   'common',
#   'interests',
#   'and',
#   'to',
#   'conduct',
#   'activities',
#   'as',
#   'approved',
#   'by',
#   'the',
#   'executive',
#   'board'],
#  ['bible', 'education'],
#  ['there',
#   'is',
#   'a',
#   'tremendous',
#   'need',
#   'for',
#   'urban',
#   'youth',
#   'to',
#   'have',
#   'after',
#   'school',
#   'employment',
#   'that',
#   'teaches',
#   'critical',
#   'academic',
#   'and',
#   'life',
#   'skills',
#   'in',
#   'an',
#   'environment',
#   'that',
#   'encourages',
#   'and',
#   'values',
#   'their',
#   'input',
#   'the',
#   'true',
#   'star',
#   'foundation',
#   'provides',
#   'services',
#   'which',
#   'eliminate',
#   'the',
#   'prime',
#   'time',
#   'hours',
#   'for',
#   'delinquent',
#   'behavior'],
#  ['true',
#   'star',
#   's',
#   'purpose',
#   'is',
#   'to',
#   'provide',
#   'a',
#   'creative',
#   'outlet',
#   'in',
#   'the',
#   'form',
#   'of',
#   'literary',
#   'and',
#   'professional',
#   'development',
#   'programs',
#   'for',
#   'youth',
#   'its',
#   'programs',
#   'expose',
#   'youth',
#   'to',
#   'real',
#   'world',
#   'experiences',
#   'particularly',
#   'in',
#   'the',
#   'fields',
#   'of',
#   'publishing',
#   'marketing',
#   'and',
#   'entertainment'],
#  ['true',
#   'star',
#   's',
#   'purpose',
#   'is',
#   'to',
#   'provide',
#   'a',
#   'creative',
#   'outlet',
#   'in',
#   'the',
#   'form',
#   'of',
#   'literary',
#   'and',
#   'professional',
#   'development',
#   'programs',
#   'for',
#   'youth',
#   'its',
#   'programs',
#   'expose',
#   'youth',
#   'to',
#   'real',
#   'world',
#   'experiences',
#   'particularly',
#   'in',
#   'the',
#   'fields',
#   'of',
#   'publishing',
#   'marketing',
#   'and',
#   'entertainment'],
#  ['the',
#   'michigan',
#   'korean',
#   'chamber',
#   'of',
#   'commerce',
#   'foundation',
#   'is',
#   'organized',
#   'exclusively',
#   'for',
#   'charitable',
#   'and',
#   'educational',
#   'purposes',
#   'the',
#   'making',
#   'of',
#   'distributions',
#   'to',
#   'organizations',
#   'under',
#   'section',
#   '501',
#   'c',
#   '3',
#   'of',
#   'the',
#   'internal',
#   'revenue',
#   'code'],
#  ['the',
#   'michigan',
#   'korean',
#   'chamber',
#   'of',
#   'commerce',
#   'foundation',
#   'is',
#   'organized',
#   'exclusively',
#   'for',
#   'charitable',
#   'and',
#   'educational',
#   'purposes',
#   'the',
#   'making',
#   'of',
#   'distributions',
#   'to',
#   'organizations',
#   'under',
#   'section',
#   '501',
#   'c',
#   '3',
#   'of',
#   'the',
#   'internal',
#   'revenue',
#   'code'],
#  ['to',
#   'save',
#   'life',
#   'property',
#   'extinguish',
#   'fire',
#   'and',
#   'serve',
#   'the',
#   'borough',
#   'of',
#   'towanda',
#   'and',
#   'contracted',
#   'areas',
#   'during',
#   'emergency',
#   'conditions'],
#  ['to',
#   'save',
#   'life',
#   'property',
#   'extinguish',
#   'fire',
#   'and',
#   'serve',
#   'the',
#   'borough',
#   'of',
#   'towanda',
#   'and',
#   'contracted',
#   'areas',
#   'during',
#   'emergency',
#   'conditions'],
#  ['vigilant',
#   'hope',
#   'is',
#   'a',
#   'modern',
#   'missions',
#   'organization',
#   'with',
#   'the',
#   'purpose',
#   'to',
#   'educate',
#   'and',
#   'equip',
#   'the',
#   'body',
#   'of',
#   'christ',
#   'to',
#   'reach',
#   'into',
#   'the',
#   'community',
#   'with',
#   'the',
#   'hope',
#   'of',
#   'the',
#   'gospel',
#   'through',
#   'urban',
#   'outreach',
#   'relief',
#   'ministry',
#   'and',
#   'educational',
#   'programs'],
#  ['vigilant',
#   'hope',
#   'is',
#   'a',
#   'modern',
#   'missions',
#   'organization',
#   'with',
#   'the',
#   'purpose',
#   'to',
#   'educate',
#   'and',
#   'equip',
#   'the',
#   'body',
#   'of',
#   'christ',
#   'to',
#   'reach',
#   'into',
#   'the',
#   'community',
#   'with',
#   'the',
#   'hope',
#   'of',
#   'the',
#   'gospel',
#   'through',
#   'urban',
#   'outreach',
#   'relief',
#   'ministry',
#   'and',
#   'educational',
#   'programs'],
#  ['vigilant',
#   'hope',
#   'is',
#   'a',
#   'modern',
#   'missions',
#   'organization',
#   'with',
#   'the',
#   'purpose',
#   'to',
#   'educate',
#   'and',
#   'equip',
#   'the',
#   'body',
#   'of',
#   'christ',
#   'to',
#   'reach',
#   'into',
#   'the',
#   'community',
#   'with',
#   'the',
#   'hope',
#   'of',
#   'the',
#   'gospel',
#   'through',
#   'urban',
#   'outreach',
#   'relief',
#   'ministry',
#   'and',
#   'educational',
#   'programs'],
#  ['jazzpa',
#   's',
#   'vision',
#   'is',
#   'to',
#   'promote',
#   'create',
#   'and',
#   'present',
#   'jazz',
#   '12',
#   'months',
#   'of',
#   'the',
#   'year',
#   'in',
#   'central',
#   'pennsylvania'],
#  ['youth', 'soccer', 'organization'],
#  ['youth', 'soccer', 'organization'],
#  ['to',
#   'provide',
#   'vetinary',
#   'and',
#   'humane',
#   'care',
#   'and',
#   'rehabilitate',
#   'animals',
#   'in',
#   'need',
#   'spay',
#   'and',
#   'neuter',
#   'rescued',
#   'animals',
#   'and',
#   'place',
#   'them',
#   'in',
#   'appropriate',
#   'and',
#   'loving',
#   'homes',
#   'educate',
#   'the',
#   'public',
#   'about',
#   'the',
#   'importance',
#   'of',
#   'animal',
#   'population',
#   'control',
#   'and',
#   'encourage',
#   'animal',
#   'rescue',
#   'activities'],
#  ['to',
#   'provide',
#   'vetinary',
#   'and',
#   'humane',
#   'care',
#   'and',
#   'rehabilitate',
#   'animals',
#   'in',
#   'need',
#   'spay',
#   'and',
#   'neuter',
#   'rescued',
#   'animals',
#   'and',
#   'place',
#   'them',
#   'in',
#   'appropriate',
#   'and',
#   'loving',
#   'homes',
#   'educate',
#   'the',
#   'public',
#   'about',
#   'the',
#   'importance',
#   'of',
#   'animal',
#   'population',
#   'control',
#   'and',
#   'encourage',
#   'animal',
#   'rescue',
#   'activities'],
#  ['to',
#   'provide',
#   'global',
#   'leadership',
#   'to',
#   'promote',
#   'integrity',
#   'and',
#   'excellence',
#   'for',
#   'the',
#   'clinical',
#   'research',
#   'profession'],
#  ['to',
#   'provide',
#   'global',
#   'leadership',
#   'to',
#   'promote',
#   'integrity',
#   'and',
#   'excellence',
#   'for',
#   'the',
#   'clinical',
#   'research',
#   'profession'],
#  ['to',
#   'provide',
#   'global',
#   'leadership',
#   'to',
#   'promote',
#   'integrity',
#   'and',
#   'excellence',
#   'for',
#   'the',
#   'clinical',
#   'research',
#   'profession'],
#  ['acrp',
#   'is',
#   'the',
#   'primary',
#   'resource',
#   'for',
#   'clinical',
#   'research',
#   'professionals',
#   'in',
#   'the',
#   'pharmaceutical',
#   'biotechnology',
#   'and',
#   'medical',
#   'device',
#   'industries',
#   'and',
#   'those',
#   'in',
#   'hospital',
#   'academic',
#   'medical',
#   'centers',
#   'and',
#   'physician',
#   'office',
#   'settings',
#   'acrp',
#   'was',
#   'founded',
#   'to',
#   'address',
#   'the',
#   'distinct',
#   'educational',
#   'and',
#   'networking',
#   'needs',
#   'of',
#   'research',
#   'nurses',
#   'and',
#   'others',
#   'who',
#   'supported',
#   'the',
#   'work',
#   'of',
#   'clinical',
#   'investigations',
#   'with',
#   'its',
#   'own',
#   'professional',
#   'society',
#   'came',
#   'the',
#   'recognition',
#   'of',
#   'a',
#   'new',
#   'distinctive',
#   'profession',
#   'that',
#   'of',
#   'the',
#   'clinical',
#   'researcher',
#   'more',
#   'than',
#   '30',
#   'years',
#   'later',
#   'acrp',
#   'is',
#   'a',
#   'global',
#   'association',
#   'comprised',
#   'of',
#   'more',
#   'than',
#   '14',
#   '000',
#   'individuals',
#   'in',
#   'over',
#   '60',
#   'countries',
#   'dedicated',
#   'to',
#   'clinical',
#   'research',
#   'and',
#   'development'],
#  ['to',
#   'provide',
#   'global',
#   'leadership',
#   'to',
#   'promote',
#   'integrity',
#   'and',
#   'excellence',
#   'for',
#   'the',
#   'clinical',
#   'research',
#   'profession'],
#  ['library',
#   'and',
#   'museum',
#   'open',
#   'to',
#   'all',
#   'visitors',
#   'as',
#   'well',
#   'as',
#   'historical',
#   'lectures'],
#  ['run', 'museum', 'and', 'library'],
#  ['run', 'museum', 'and', 'library'],
#  ['conduct', 'public', 'activities'],
#  ['conduct',
#   'public',
#   'activities',
#   'promoting',
#   'and',
#   'educating',
#   'about',
#   'the',
#   'outdoors',
#   'including',
#   'beauty',
#   'pageants',
#   'wildlife',
#   'contests',
#   'and',
#   'educational',
#   'seminars',
#   'and',
#   'shows'],
#  ['conduct', 'public', 'activities'],
#  ['conduct', 'public', 'activities'],
#  ['conduct', 'public', 'activities'],
#  ['the',
#   'mission',
#   'is',
#   'to',
#   'introduce',
#   'boys',
#   'and',
#   'girls',
#   'to',
#   'the',
#   'game',
#   'of',
#   'baseball',
#   'in',
#   'a',
#   'structured',
#   'and',
#   'competitive',
#   'atmosphere'],
#  ['the',
#   'mission',
#   'is',
#   'to',
#   'introduce',
#   'boys',
#   'and',
#   'girls',
#   'to',
#   'the',
#   'game',
#   'of',
#   'baseball',
#   'in',
#   'a',
#   'structured',
#   'and',
#   'competitive',
#   'atmosphere'],
#  ['the',
#   'mission',
#   'is',
#   'to',
#   'introduce',
#   'boys',
#   'and',
#   'girls',
#   'to',
#   'the',
#   'game',
#   'of',
#   'baseball',
#   'in',
#   'a',
#   'structured',
#   'and',
#   'competitive',
#   'atmosphere'],
#  ['the',
#   'mission',
#   'is',
#   'to',
#   'introduce',
#   'boys',
#   'and',
#   'girls',
#   'to',
#   'the',
#   'game',
#   'of',
#   'baseball',
#   'in',
#   'a',
#   'structured',
#   'and',
#   'competitive',
#   'atmosphere'],
#  ['protecing', 'our', 'future', 'while', 'preserving', 'our', 'past'],
#  ['protecing', 'our', 'future', 'while', 'preserving', 'our', 'past'],
#  ['reaching',
#   'out',
#   'to',
#   'both',
#   'members',
#   'and',
#   'potental',
#   'members',
#   'and',
#   'the',
#   'public',
#   'in',
#   'general',
#   'regarding',
#   'safety',
#   'and',
#   'drugs',
#   'and',
#   'general',
#   'public',
#   'issues',
#   'keeping',
#   'members',
#   'informed',
#   'of',
#   'issues',
#   'involving',
#   'retires',
#   'police'],
#  ['reaching',
#   'out',
#   'to',
#   'both',
#   'members',
#   'potental',
#   'members',
#   'and',
#   'the',
#   'public',
#   'in',
#   'general',
#   'regarding',
#   'safety',
#   'and',
#   'drugs',
#   'and',
#   'general',
#   'public',
#   'issues',
#   'keeping',
#   'members',
#   'informed',
#   'of',
#   'issues',
#   'involving',
#   'retired',
#   'police'],
#  ['watercolor',
#   'west',
#   'was',
#   'formed',
#   'to',
#   'preserve',
#   'the',
#   'traditional',
#   'technique',
#   'of',
#   'transparent',
#   'watercolor',
#   'painting',
#   'to',
#   'promote',
#   'and',
#   'advance',
#   'the',
#   'appreciation',
#   'of',
#   'purely',
#   'transparent',
#   'watercolor',
#   'painting',
#   'through',
#   'education',
#   'exhibition',
#   'and',
#   'community',
#   'service'],
#  ['watercolor',
#   'west',
#   'was',
#   'formed',
#   'to',
#   'preserve',
#   'the',
#   'traditional',
#   'technique',
#   'of',
#   'transparent',
#   'watercolor',
#   'painting',
#   'to',
#   'promote',
#   'and',
#   'advance',
#   'the',
#   'appreciation',
#   'of',
#   'purely',
#   'transparent',
#   'watercolor',
#   'painting',
#   'through',
#   'education',
#   'exhibition',
#   'and',
#   'community',
#   'service'],
#  ['watercolor',
#   'west',
#   'was',
#   'formed',
#   'to',
#   'preserve',
#   'the',
#   'traditional',
#   'technique',
#   'of',
#   'transparent',
#   'watercolor',
#   'painting',
#   'to',
#   'promote',
#   'and',
#   'advance',
#   'the',
#   'appreciation',
#   'of',
#   'purely',
#   'transparent',
#   'watercolor',
#   'painting',
#   'through',
#   'education',
#   'exhibition',
#   'and',
#   'community',
#   'service'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['promotion',
#   'and',
#   'inducement',
#   'of',
#   'general',
#   'commercial',
#   'activity',
#   'in',
#   'the',
#   'fremont',
#   'area'],
#  ['to',
#   'encourage',
#   'friendship',
#   'within',
#   'the',
#   'community',
#   'to',
#   'promote',
#   'the',
#   'civic',
#   'and',
#   'social',
#   'welfare',
#   'of',
#   'the',
#   'community',
#   'to',
#   'assist',
#   'youth',
#   'organizations',
#   'to',
#   'hold',
#   'educational',
#   'programs',
#   'and',
#   'to',
#   'elevate',
#   'the',
#   'intellectual',
#   'and',
#   'social',
#   'plane',
#   'of',
#   'members',
#   'in',
#   'the',
#   'interest',
#   'of',
#   'higher',
#   'standards',
#   'of',
#   'citizenship'],
#  ['providing',
#   'team',
#   'sport',
#   'opportunities',
#   'to',
#   'children',
#   'within',
#   'local',
#   'community'],
#  ['providing',
#   'team',
#   'sport',
#   'opportunities',
#   'to',
#   'children',
#   'within',
#   'local',
#   'community'],
#  ['providing',
#   'team',
#   'sport',
#   'opportunities',
#   'to',
#   'children',
#   'within',
#   'local',
#   'community'],
#  ['volenteer',
#   'fire',
#   'company',
#   'offering',
#   'public',
#   'service',
#   'rescue',
#   'and',
#   'ambulance'],
#  ['the',
#   'offer',
#   'educational',
#   'and',
#   'interactive',
#   'exhibits',
#   'for',
#   'children',
#   'bringing',
#   'families',
#   'together',
#   'in',
#   'a',
#   'safe',
#   'environment',
#   'emphasize',
#   'the',
#   'importance',
#   'of',
#   'the',
#   'family',
#   'values',
#   'and',
#   'spark',
#   'the',
#   'imagination',
#   'which',
#   'inspires',
#   'learning',
#   'and',
#   'nurturing',
#   'growth',
#   'through',
#   'play'],
#  ['to',
#   'offer',
#   'educational',
#   'and',
#   'interactive',
#   'exhibits',
#   'for',
#   'children',
#   'bringing',
#   'families',
#   'together',
#   'in',
#   'a',
#   'safe',
#   'environment',
#   'emphasize',
#   'the',
#   'importance',
#   'of',
#   'the',
#   'family',
#   'values',
#   'and',
#   'spark',
#   'the',
#   'imagination',
#   'which',
#   'inspires',
#   'learning',
#   'and',
#   'nurturing',
#   'growth',
#   'through',
#   'play'],
#  ['organize', 'and', 'educate', 'wayward', 'students'],
#  ['missions',
#   'to',
#   'haiti',
#   'scholarship',
#   'funds',
#   'hurricane',
#   'relief',
#   'earth',
#   'quake',
#   'relief',
#   'stabilization',
#   'of',
#   'the',
#   'carma',
#   'orphans',
#   'stabilization',
#   'of',
#   'village',
#   'theodat',
#   'and',
#   'lassare',
#   'organizing',
#   'relief',
#   'food',
#   'and',
#   'good',
#   'drives'],
#  ['religious', 'services'],
#  ['religious', 'services'],
#  ['to',
#   'assist',
#   'people',
#   'in',
#   'the',
#   'general',
#   'community',
#   'in',
#   'times',
#   'of',
#   'need',
#   'whether',
#   'it',
#   'be',
#   'for',
#   'emotional',
#   'spiritual',
#   'or',
#   'financial',
#   'reasons',
#   'in',
#   'a',
#   'christian',
#   'method'],
#  ['to',
#   'assist',
#   'people',
#   'in',
#   'the',
#   'general',
#   'community',
#   'in',
#   'times',
#   'of',
#   'need',
#   'whether',
#   'it',
#   'be',
#   'for',
#   'emotional',
#   'spiritual',
#   'or',
#   'financial',
#   'reasons',
#   'in',
#   'a',
#   'christian',
#   'method'],
#  ['to',
#   'assist',
#   'people',
#   'in',
#   'the',
#   'general',
#   'community',
#   'in',
#   'times',
#   'of',
#   'need',
#   'whether',
#   'it',
#   'be',
#   'for',
#   'emotional',
#   'spiritual',
#   'or',
#   'financial',
#   'reasons',
#   'in',
#   'a',
#   'christian',
#   'method'],
#  ['to',
#   'support',
#   'education',
#   'and',
#   'learning',
#   'of',
#   'the',
#   'arts',
#   'around',
#   'the',
#   'world',
#   'specifically',
#   'associated',
#   'with',
#   'hughes',
#   'school',
#   'in',
#   'cochabamba',
#   'bolivia'],
#  ['organization',
#   'dedicated',
#   'to',
#   'enhancing',
#   'lives',
#   'and',
#   'fostering',
#   'communities',
#   'through',
#   'education',
#   'preventive',
#   'justice',
#   'for',
#   'youth',
#   'urban',
#   'development',
#   'adolescents',
#   'in',
#   'transition',
#   'and',
#   'aging',
#   'and',
#   'elder',
#   'services'],
#  ['to',
#   'encourage',
#   'involvement',
#   'between',
#   'school',
#   'community',
#   'parents',
#   'guardians',
#   'children',
#   'and',
#   'teachers'],
#  ['santa',
#   'monica',
#   'united',
#   'football',
#   'club',
#   'is',
#   'a',
#   'youth',
#   'club',
#   'organized',
#   'to',
#   'provide',
#   'coaching',
#   'promote',
#   'the',
#   'development',
#   'of',
#   'soccer',
#   'skills',
#   'and',
#   'sportsmanship',
#   'and',
#   'to',
#   'encourage',
#   'amateur',
#   'athletic',
#   'competition',
#   'every',
#   'player',
#   'participates',
#   'in',
#   'league',
#   'competition',
#   'as',
#   'well',
#   'as',
#   '10',
#   't0',
#   '12',
#   'local',
#   'and',
#   'national',
#   'turnaments'],
#  ['santa',
#   'monica',
#   'united',
#   'football',
#   'club',
#   'is',
#   'a',
#   'youth',
#   'club',
#   'organized',
#   'to',
#   'provide',
#   'coaching',
#   'promote',
#   'the',
#   'development',
#   'of',
#   'soccer',
#   'skills',
#   'and',
#   'sportsmanship',
#   'and',
#   'to',
#   'encourage',
#   'amateur',
#   'athletic',
#   'competition',
#   'every',
#   'player',
#   'participates',
#   'in',
#   'league',
#   'competition',
#   'as',
#   'well',
#   'as',
#   '10',
#   't0',
#   '12',
#   'local',
#   'and',
#   'national',
#   'turnaments'],
#  ['santa',
#   'monica',
#   'united',
#   'football',
#   'club',
#   'is',
#   'a',
#   'youth',
#   'club',
#   'organized',
#   'to',
#   'provide',
#   'coaching',
#   'promote',
#   'the',
#   'development',
#   'of',
#   'soccer',
#   'skills',
#   'and',
#   'sportsmanship',
#   'and',
#   'to',
#   'encourage',
#   'amateur',
#   'athletic',
#   'competition',
#   'every',
#   'player',
#   'participates',
#   'in',
#   'league',
#   'competition',
#   'as',
#   'well',
#   'as',
#   '10',
#   't0',
#   '12',
#   'local',
#   'and',
#   'national',
#   'turnaments'],
#  ['risk',
#   'management',
#   'specialty',
#   'crop',
#   'education',
#   'and',
#   'training',
#   'to',
#   'socially',
#   'disadvantaged',
#   'farmers'],
#  ['christian',
#   'centered',
#   'recovery',
#   'based',
#   'services',
#   'for',
#   'the',
#   'homeless',
#   'recovering',
#   'addicts',
#   'alcoholics',
#   'and',
#   'ex',
#   'offenders',
#   'to',
#   'help',
#   'them',
#   'successfully',
#   'reenter',
#   'into',
#   'the',
#   'community'],
#  ['construct',
#   'and',
#   'maintain',
#   'a',
#   'memorial',
#   'to',
#   'those',
#   'lives',
#   'lost',
#   'during',
#   'the',
#   'skywalk',
#   'collapse'],
#  ['construct',
#   'and',
#   'maintain',
#   'a',
#   'memorial',
#   'to',
#   'those',
#   'lives',
#   'lost',
#   'during',
#   'the',
#   'skywalk',
#   'collapse'],
#  ['to',
#   'enhance',
#   'and',
#   'promote',
#   'musical',
#   'performances',
#   'of',
#   'all',
#   'kinds',
#   'of',
#   'ensembles',
#   'such',
#   'as',
#   'orchestras',
#   'chamber',
#   'ensembles',
#   'and',
#   'solo',
#   'recitals',
#   'by',
#   'providing',
#   'a',
#   'variety',
#   'of',
#   'performance',
#   'opportunities',
#   'and',
#   'personal',
#   'networks',
#   'to',
#   'members',
#   'of',
#   'musicians',
#   'in',
#   'new',
#   'york',
#   'so',
#   'that',
#   'it',
#   'achieves',
#   'expanding',
#   'and',
#   'promoting',
#   'classical',
#   'music',
#   'activities',
#   'in',
#   'metropolitan',
#   'areas',
#   'and',
#   'in',
#   'the',
#   'united',
#   'states'],
#  ['to',
#   'enhance',
#   'and',
#   'promote',
#   'musical',
#   'performances',
#   'of',
#   'all',
#   'kinds',
#   'of',
#   'ensembles',
#   'such',
#   'as',
#   'orchestras',
#   'chamber',
#   'ensembles',
#   'and',
#   'solo',
#   'recitals',
#   'by',
#   'providing',
#   'a',
#   'variety',
#   'of',
#   'performance',
#   'opportunities',
#   'and',
#   'personal',
#   'networks',
#   'to',
#   'members',
#   'of',
#   'musicians',
#   'in',
#   'new',
#   'york',
#   'so',
#   'that',
#   'it',
#   'achieves',
#   'expanding',
#   'and',
#   'promoting',
#   'classical',
#   'music',
#   'activities',
#   'in',
#   'metropolitan',
#   'areas',
#   'and',
#   'in',
#   'the',
#   'united',
#   'states'],
#  ['triangle',
#   'cricket',
#   'league',
#   'tcl',
#   'is',
#   'a',
#   'nonprofit',
#   'based',
#   'around',
#   'the',
#   'triangle',
#   'region',
#   'of',
#   'north',
#   'carolina',
#   'encompassing',
#   'raleigh',
#   'durham',
#   'cary',
#   'and',
#   'chapel',
#   'hill',
#   'the',
#   'tcls',
#   'mission',
#   'is',
#   'to',
#   'play',
#   'and',
#   'promote',
#   'the',
#   'game',
#   'of',
#   'cricket',
#   'in',
#   'the',
#   'triangle',
#   'region',
#   'amongst',
#   'both',
#   'adult',
#   'youth',
#   'and',
#   'women',
#   'players'],
#  ['support', 'high', 'school', 'theater', 'program'],
#  ['the',
#   'mission',
#   'of',
#   'the',
#   'detours',
#   'mentoring',
#   'group',
#   'is',
#   'dedicated',
#   'to',
#   'enhance',
#   'the',
#   'empowerment',
#   'of',
#   'at',
#   'risk',
#   'youth',
#   'in',
#   'our',
#   'community',
#   'to',
#   'enable',
#   'the',
#   'youth',
#   'to',
#   'make',
#   'positive',
#   'life',
#   'choices',
#   'that',
#   'will',
#   'benefit',
#   'and',
#   'maximize',
#   'their',
#   'personal',
#   'potential',
#   'committed',
#   'to',
#   'being',
#   'a',
#   'pillar',
#   'in',
#   'the',
#   'community',
#   'instill',
#   'a',
#   'progressive',
#   'sense',
#   'of',
#   'life',
#   'career',
#   'planning',
#   'and',
#   'achievement',
#   'our',
#   'goal',
#   'is',
#   'to',
#   'reach',
#   'the',
#   'youth',
#   'between',
#   '12',
#   'thru',
#   '18',
#   'years',
#   'by',
#   'reaching',
#   'out',
#   'to',
#   'them',
#   'right',
#   'where',
#   'their',
#   'need',
#   'may',
#   'be'],
#  ['the',
#   'mission',
#   'of',
#   'the',
#   'detours',
#   'mentoring',
#   'group',
#   'is',
#   'dedicated',
#   'to',
#   'enhance',
#   'the',
#   'empowerment',
#   'of',
#   'at',
#   'risk',
#   'youth',
#   'in',
#   'our',
#   'community',
#   'to',
#   'enable',
#   'the',
#   'youth',
#   'to',
#   'make',
#   'positive',
#   'life',
#   'choices',
#   'that',
#   'will',
#   'benefit',
#   'and',
#   'maximize',
#   'their',
#   'personal',
#   'potential',
#   'committed',
#   'to',
#   'being',
#   'a',
#   'pillar',
#   'in',
#   'the',
#   'community',
#   'instill',
#   'a',
#   'progressive',
#   'sense',
#   'of',
#   'life',
#   'career',
#   'planning',
#   'and',
#   'achievement',
#   'our',
#   'goal',
#   'is',
#   'to',
#   'reach',
#   'the',
#   'youth',
#   'between',
#   '12',
#   'thru',
#   '18',
#   'years',
#   'by',
#   'reaching',
#   'out',
#   'to',
#   'them',
#   'right',
#   'where',
#   'their',
#   'need',
#   'may',
#   'be'],
#  ['our',
#   'mission',
#   'is',
#   'to',
#   'be',
#   'among',
#   'the',
#   'first',
#   'responders',
#   'in',
#   'any',
#   'emergency',
#   'situation',
#   'we',
#   'strive',
#   'daily',
#   'to',
#   'connect',
#   'with',
#   'reach',
#   'and',
#   'integrate',
#   'with',
#   'people',
#   'from',
#   'all',
#   'nations'],
#  ['to',
#   'raise',
#   'money',
#   'for',
#   'youth',
#   'scholarships',
#   'and',
#   'sickle',
#   'cell',
#   'awareness'],
#  ['public',
#   'charity',
#   'status',
#   'qualified',
#   'to',
#   'receive',
#   'tax',
#   'deductible',
#   'bequets',
#   'devises',
#   'transfers',
#   'or',
#   'gifts'],
#  ['to',
#   'provide',
#   'disaster',
#   'assistance',
#   'to',
#   'those',
#   'affected',
#   'by',
#   'natural',
#   'disasters'],
#  ['to',
#   'provide',
#   'disaster',
#   'assistance',
#   'to',
#   'those',
#   'affected',
#   'by',
#   'natural',
#   'disasters'],
#  ['to', 'educate', 'the', 'community', 'through', 'christiananity'],
#  ['it',
#   'is',
#   'the',
#   'mission',
#   'duty',
#   'and',
#   'purpose',
#   'of',
#   'al',
#   'baqee',
#   'organization',
#   'nfp',
#   'hereinafter',
#   'referred',
#   'to',
#   'as',
#   'al',
#   'baqee',
#   'to',
#   'address',
#   'educate',
#   'coordinate',
#   'and',
#   'provide',
#   'awareness',
#   'about',
#   'the',
#   'atrocities',
#   'and',
#   'violence',
#   'brought',
#   'upon',
#   'the',
#   'people',
#   'of',
#   'various',
#   'religious',
#   'denominations',
#   'and',
#   'their',
#   'respective',
#   'religious',
#   'and',
#   'cultural',
#   'heritage'],
#  ['it',
#   'is',
#   'the',
#   'mission',
#   'duty',
#   'and',
#   'purpose',
#   'of',
#   'al',
#   'baqee',
#   'organization',
#   'nfp',
#   'hereinafter',
#   'referred',
#   'to',
#   'as',
#   'al',
#   'baqee',
#   'to',
#   'address',
#   'educate',
#   'coordinate',
#   'and',
#   'provide',
#   'awareness',
#   'about',
#   'the',
#   'atrocities',
#   'and',
#   'violence',
#   'brought',
#   'upon',
#   'the',
#   'people',
#   'of',
#   'various',
#   'religious',
#   'denominations',
#   'and',
#   'their',
#   'respective',
#   'religious',
#   'and',
#   'cultural',
#   'heritage'],
#  ['america',
#   'nepal',
#   'helping',
#   'society',
#   'is',
#   'organized',
#   'exclusively',
#   'for',
#   'charitable',
#   'language',
#   'and',
#   'educational',
#   'purpose',
#   'including',
#   'for',
#   'such',
#   'purposes',
#   'the',
#   'making',
#   'of',
#   'distribution',
#   'to',
#   'orginazations',
#   'that',
#   'qualify',
#   'as',
#   'exempt',
#   'organization',
#   'under',
#   '501c',
#   '3',
#   'of',
#   'the',
#   'internal',
#   'revenue',
#   'code',
#   'or',
#   'corresponding',
#   'section'],
#  ['america',
#   'nepal',
#   'helping',
#   'society',
#   'is',
#   'organized',
#   'exclusively',
#   'for',
#   'charitable',
#   'language',
#   'and',
#   'educational',
#   'purpose',
#   'including',
#   'for',
#   'such',
#   'purposes',
#   'the',
#   'making',
#   'of',
#   'distribution',
#   'to',
#   'orginazations',
#   'that',
#   'qualify',
#   'as',
#   'exempt',
#   'organization',
#   'under',
#   '501c',
#   '3',
#   'of',
#   'the',
#   'internal',
#   'revenue',
#   'code',
#   'or',
#   'corresponding',
#   'section'],
#  ['america',
#   'nepal',
#   'helping',
#   'society',
#   'is',
#   'organized',
#   'exclusively',
#   'for',
#   'charitable',
#   'language',
#   'and',
#   'educational',
#   'purpose',
#   'including',
#   'for',
#   'such',
#   'purposes',
#   'the',
#   'making',
#   'of',
#   'distribution',
#   'to',
#   'orginazations',
#   'that',
#   'qualify',
#   'as',
#   'exempt',
#   'organization',
#   'under',
#   '501c',
#   '3',
#   'of',
#   'the',
#   'internal',
#   'revenue',
#   'code',
#   'or',
#   'corresponding',
#   'section'],
#  ['to',
#   'lift',
#   'up',
#   'and',
#   'empower',
#   'people',
#   'in',
#   'need',
#   'focusing',
#   'on',
#   'their',
#   'total',
#   'well',
#   'being',
#   'mind',
#   'body',
#   'and',
#   'soul'],
#  ['daylight',
#   'magazine',
#   'is',
#   'the',
#   'printed',
#   'publication',
#   'of',
#   'daylight',
#   'community',
#   'arts',
#   'foundation',
#   'inc'],
#  ['daylight',
#   'magazine',
#   'is',
#   'the',
#   'printed',
#   'publication',
#   'of',
#   'daylight',
#   'community',
#   'arts',
#   'foundation',
#   'inc'],
#  ['daylight',
#   'magazine',
#   'is',
#   'the',
#   'printed',
#   'publication',
#   'of',
#   'daylight',
#   'community',
#   'arts',
#   'foundation',
#   'inc'],
#  ['daylight',
#   'magazine',
#   'is',
#   'the',
#   'printed',
#   'publication',
#   'of',
#   'daylight',
#   'community',
#   'arts',
#   'foundation',
#   'inc'],
#  ['to', 'enhance', 'dance', 'amongst', 'the', 'adolescent', 'community'],
#  ['to', 'enhance', 'dance', 'amongst', 'the', 'adolescent', 'community'],
#  ['the',
#   'schools',
#   'mission',
#   'is',
#   'to',
#   'educate',
#   'students',
#   'by',
#   'operating',
#   'a',
#   'charter',
#   'school',
#   'in',
#   'arizona'],
#  ['the',
#   'schools',
#   'mission',
#   'is',
#   'to',
#   'educate',
#   'students',
#   'by',
#   'operating',
#   'a',
#   'charter',
#   'school',
#   'in',
#   'arizona'],
#  ['the',
#   'schools',
#   'mission',
#   'is',
#   'to',
#   'educate',
#   'students',
#   'by',
#   'operating',
#   'a',
#   'charter',
#   'school',
#   'in',
#   'arizona'],
#  ['we',
#   'help',
#   'develop',
#   'great',
#   'international',
#   'leaders',
#   'who',
#   'will',
#   'sustain',
#   'our',
#   'environment',
#   'promote',
#   'international',
#   'peace',
#   'and',
#   'create',
#   'a',
#   'high',
#   'quality',
#   'of',
#   'life',
#   'for',
#   'all',
#   'we',
#   'educate',
#   'and',
#   'support',
#   'these',
#   'leaders',
#   'to',
#   'get',
#   'free',
#   'or',
#   'affordable',
#   'access',
#   'to',
#   'high',
#   'quality',
#   'leadership',
#   'coaching',
#   'we',
#   'recruit',
#   'highly',
#   'qualified',
#   'leadership',
#   'coaches',
#   'who',
#   'are',
#   'committed',
#   'to',
#   'giving',
#   'the',
#   'gift',
#   'of',
#   'their',
#   'coaching',
#   'to',
#   'the',
#   'international',
#   'leaders',
#   'we',
#   'provide',
#   'access',
#   'to',
#   'those',
#   'coaches',
#   'and',
#   'advise',
#   'and',
#   'support',
#   'the',
#   'coaches',
#   'to',
#   'best',
#   'serve',
#   'the',
#   'leaders',
#   'we',
#   'inform',
#   'the',
#   'leaders',
#   'about',
#   'the',
#   'benefits',
#   'and',
#   'best',
#   'ways',
#   'to',
#   'select',
#   'and',
#   'work',
#   'with',
#   'coaches',
#   'we',
#   'help',
#   'them',
#   'identify',
#   'the',
#   'coaches',
#   'who',
#   'can',
#   'best',
#   'help',
#   'them',
#   'develop',
#   'their',
#   'leadership',
#   'capabilities',
#   'and',
#   'have',
#   'greater',
#   'positive',
#   'impact',
#   'on',
#   'the',
#   'world',
#   'we',
#   'conduct',
#   'confidential',
#   'research',
#   'on',
#   'best',
#   'coaching',
#   'practices',
#   'through',
#   'all',
#   'of',
#   'these',
#   'activities',
#   'we',
#   'help',
#   'build',
#   'an',
#   'international',
#   'community',
#   'of',
#   'leadership',
#   'coaching',
#   'for',
#   'the',
#   'benefit',
#   'of',
#   'humanity'],
#  ['we',
#   'help',
#   'develop',
#   'great',
#   'international',
#   'leaders',
#   'who',
#   'will',
#   'sustain',
#   'our',
#   'environment',
#   'promote',
#   'international',
#   'peace',
#   'and',
#   'create',
#   'a',
#   'high',
#   'quality',
#   'of',
#   'life',
#   'for',
#   'all',
#   'we',
#   'educate',
#   'and',
#   'support',
#   'these',
#   'leaders',
#   'to',
#   'get',
#   'free',
#   'or',
#   'affordable',
#   'access',
#   'to',
#   'high',
#   'quality',
#   'leadership',
#   'coaching',
#   'we',
#   'recruit',
#   'highly',
#   'qualified',
#   'leadership',
#   'coaches',
#   'who',
#   'are',
#   'committed',
#   'to',
#   'giving',
#   'the',
#   'gift',
#   'of',
#   'their',
#   'coaching',
#   'to',
#   'the',
#   'international',
#   'leaders',
#   'we',
#   'provide',
#   'access',
#   'to',
#   'those',
#   'coaches',
#   'and',
#   'advise',
#   'and',
#   'support',
#   'the',
#   'coaches',
#   'to',
#   'best',
#   'serve',
#   'the',
#   'leaders',
#   'we',
#   'inform',
#   'the',
#   'leaders',
#   'about',
#   'the',
#   'benefits',
#   'and',
#   'best',
#   'ways',
#   'to',
#   'select',
#   'and',
#   'work',
#   'with',
#   'coaches',
#   'we',
#   'help',
#   'them',
#   'identify',
#   'the',
#   'coaches',
#   'who',
#   'can',
#   'best',
#   'help',
#   'them',
#   'develop',
#   'their',
#   'leadership',
#   'capabilities',
#   'and',
#   'have',
#   'greater',
#   'positive',
#   'impact',
#   'on',
#   'the',
#   'world',
#   'we',
#   'conduct',
#   'confidential',
#   'research',
#   'on',
#   'best',
#   'coaching',
#   'practices',
#   'through',
#   'all',
#   'of',
#   'these',
#   'activities',
#   'we',
#   'help',
#   'build',
#   'an',
#   'international',
#   'community',
#   'of',
#   'leadership',
#   'coaching',
#   'for',
#   'the',
#   'benefit',
#   'of',
#   'humanity'],
#  ['summer', 'food', 'service', 'program'],
#  ['summer', 'food', 'service', 'program'],
#  ['summer',
#   'food',
#   'service',
#   'program',
#   'and',
#   'youth',
#   'enrichment',
#   'program'],
#  ['to',
#   'assist',
#   'young',
#   'people',
#   'in',
#   'their',
#   'development',
#   'of',
#   'knowledge',
#   'skills',
#   'and',
#   'love',
#   'for',
#   'the',
#   'game',
#   'of',
#   'basketball'],
#  ['to',
#   'assist',
#   'young',
#   'people',
#   'in',
#   'their',
#   'development',
#   'of',
#   'knowledge',
#   'skills',
#   'and',
#   'love',
#   'for',
#   'the',
#   'game',
#   'of',
#   'basketball'],
#  ['assisting',
#   'young',
# ...
#   'school',
#   'district',
#   'one',
#   'by',
#   'providing',
#   'aid',
#   'to',
#   'families',
#   'for',
#   'household',
#   'bills',
#   'or',
#   'hotel',
#   'restaurant',
#   'vouchers',
#   'in',
#   'emergency',
#   'situations'],
#  ['snac',
#   'is',
#   'a',
#   'non',
#   'profit',
#   'organization',
#   'dedicated',
#   'to',
#   'decrease',
#   'the',
#   'number',
#   'of',
#   'homeless',
#   'indigent',
#   'and',
#   'hungry',
#   'children',
#   'in',
#   'florence',
#   'school',
#   'district',
#   'one',
#   'by',
#   'providing',
#   'aid',
#   'to',
#   'families',
#   'for',
#   'household',
#   'bills',
#   'or',
#   'hotel',
#   'restaurant',
#   'vouchers',
#   'in',
#   'emergency',
#   'situations'],
#  ['to',
#   'provide',
#   'a',
#   'rescue',
#   'shelter',
#   'for',
#   'animals',
#   'that',
#   'have',
#   'been',
#   'abandoned',
#   'abused',
#   'neglected',
#   'or',
#   'are',
#   'unwanted',
#   'and',
#   'to',
#   'provide',
#   'for',
#   'neutering',
#   'and',
#   'adoptions',
#   'of',
#   'animals',
#   'that',
#   'have',
#   'been',
#   'placed',
#   'in',
#   'the',
#   'rescue',
#   'shelter'],
#  ['go',
#   'pantry',
#   'strives',
#   'to',
#   'make',
#   'a',
#   'positive',
#   'impact',
#   'on',
#   'local',
#   'kids',
#   'by',
#   'providing',
#   'food',
#   'to',
#   'those',
#   'who',
#   'are',
#   'hungry',
#   'specifically',
#   'go',
#   'pantry',
#   'helps',
#   'hungry',
#   'school',
#   'age',
#   'children',
#   'in',
#   'boone',
#   'county',
#   'who',
#   'do',
#   'not',
#   'have',
#   'enough',
#   'to',
#   'eat',
#   'on',
#   'days',
#   'they',
#   'are',
#   'away',
#   'from',
#   'school'],
#  ['to',
#   'provide',
#   'meaningful',
#   'instructions',
#   'in',
#   'horsemanship',
#   'that',
#   'accommodate',
#   'and',
#   'enhance',
#   'the',
#   'quality',
#   'of',
#   'life',
#   'of',
#   'those',
#   'challenged',
#   'by',
#   'physical',
#   'cognitive',
#   'emotional',
#   'and',
#   'or',
#   'social',
#   'constraints'],
#  ['behavioral',
#   'health',
#   'clinic',
#   'commited',
#   'to',
#   'providing',
#   'medical',
#   'clinical',
#   'management',
#   'to',
#   'children',
#   'adolescents',
#   'adults',
#   'and',
#   'famalies',
#   'living',
#   'in',
#   'the',
#   'district',
#   'of',
#   'columbia',
#   'so',
#   'they',
#   'may',
#   'function',
#   'to',
#   'their',
#   'full',
#   'potential'],
#  ['behavioral',
#   'health',
#   'clinic',
#   'commited',
#   'to',
#   'providing',
#   'medical',
#   'clinical',
#   'management',
#   'to',
#   'children',
#   'adolescents',
#   'adults',
#   'and',
#   'famalies',
#   'living',
#   'in',
#   'the',
#   'district',
#   'of',
#   'columbia',
#   'so',
#   'they',
#   'may',
#   'function',
#   'to',
#   'their',
#   'full',
#   'potential'],
#  ['behavioral',
#   'health',
#   'clinic',
#   'commited',
#   'to',
#   'providing',
#   'medical',
#   'clinical',
#   'management',
#   'to',
#   'children',
#   'adolescents',
#   'adults',
#   'and',
#   'famalies',
#   'living',
#   'in',
#   'the',
#   'district',
#   'of',
#   'columbia',
#   'so',
#   'they',
#   'may',
#   'function',
#   'to',
#   'their',
#   'full',
#   'potential'],
#  ['to',
#   'foster',
#   'coordinate',
#   'and',
#   'catalyze',
#   'initiatives',
#   'that',
#   'improve',
#   'the',
#   'business',
#   'climate',
#   'and',
#   'quality',
#   'of',
#   'life',
#   'in',
#   'east',
#   'new',
#   'orleans',
#   'through',
#   'business',
#   'development',
#   'infrastructure',
#   'improvement',
#   'and',
#   'image',
#   'enhacement',
#   'in',
#   'order',
#   'to',
#   'grow',
#   'good',
#   'jobs',
#   'investments',
#   'and',
#   'tax',
#   'revenue',
#   'in',
#   'the',
#   'city',
#   'of',
#   'new',
#   'orleans'],
#  ['to',
#   'foster',
#   'coordinate',
#   'and',
#   'catalyze',
#   'initiatives',
#   'that',
#   'improve',
#   'the',
#   'business',
#   'climate',
#   'and',
#   'quality',
#   'of',
#   'life',
#   'in',
#   'east',
#   'new',
#   'orleans',
#   'through',
#   'business',
#   'development',
#   'infrastructure',
#   'improvement',
#   'and',
#   'image',
#   'enhacement',
#   'in',
#   'order',
#   'to',
#   'grow',
#   'good',
#   'jobs',
#   'investments',
#   'and',
#   'tax',
#   'revenue',
#   'in',
#   'the',
#   'city',
#   'of',
#   'new',
#   'orleans'],
#  ['charitable', 'activities'],
#  ['charitable', 'activities'],
#  ['charitable', 'activities'],
#  ['provide',
#   'educational',
#   'services',
#   'to',
#   'community',
#   'public',
#   'with',
#   'focus',
#   'on',
#   'the',
#   'russian',
#   'language',
#   'and',
#   'literature'],
#  ['provide',
#   'educational',
#   'services',
#   'to',
#   'community',
#   'public',
#   'with',
#   'focus',
#   'on',
#   'the',
#   'russian',
#   'language',
#   'and',
#   'literature'],
#  ['provide',
#   'educational',
#   'services',
#   'to',
#   'community',
#   'public',
#   'with',
#   'focus',
#   'on',
#   'the',
#   'russian',
#   'language',
#   'and',
#   'literature'],
#  ['religious', 'ministry', 'and', 'community', 'support'],
#  ['our',
#   'mission',
#   'is',
#   'to',
#   'serve',
#   'our',
#   'nation',
#   's',
#   'veterans',
#   'by',
#   'growing',
#   'and',
#   'donating',
#   'high',
#   'quality',
#   'fruits',
#   'vegetables',
#   'and',
#   'flower',
#   'bouquets',
#   'to',
#   'veterans',
#   'and',
#   'their',
#   'caregivers',
#   'free',
#   'of',
#   'charge'],
#  ['to',
#   'provide',
#   'training',
#   'mentoring',
#   'financial',
#   'support',
#   'and',
#   'volunteer',
#   'teams'],
#  ['the',
#   'organization',
#   'supports',
#   'the',
#   'catholic',
#   'church',
#   'by',
#   'producing',
#   'and',
#   'broadcasting',
#   'religious',
#   'programming',
#   'via',
#   'various',
#   'media',
#   'platforms'],
#  ['the',
#   'organization',
#   'supports',
#   'the',
#   'catholic',
#   'church',
#   'by',
#   'producing',
#   'and',
#   'broadcasting',
#   'religious',
#   'programming',
#   'via',
#   'various',
#   'media',
#   'platforms'],
#  ['to',
#   'support',
#   'and',
#   'enhance',
#   'the',
#   'advancement',
#   'of',
#   'cheering',
#   'activities'],
#  ['the',
#   'mission',
#   'of',
#   'stone',
#   's',
#   'throw',
#   'christian',
#   'ministry',
#   'inc',
#   'is',
#   'to',
#   'glorify',
#   'god',
#   'by',
#   'providing',
#   'our',
#   'assistance',
#   'to',
#   'individuals',
#   'churches',
#   'mission',
#   'teams',
#   'and',
#   'other',
#   'agencies',
#   'we',
#   'gather',
#   'and',
#   'strive',
#   'to',
#   'provide',
#   'the',
#   'resources',
#   'needed',
#   'to',
#   'assist',
#   'those',
#   'who',
#   'are',
#   'hurting',
#   'our',
#   'ministry',
#   'uses',
#   'crises',
#   'to',
#   'meet',
#   'the',
#   'spiritual',
#   'needs',
#   'of',
#   'others',
#   'our',
#   'most',
#   'important',
#   'goal',
#   'is',
#   'to',
#   'share',
#   'the',
#   'love',
#   'of',
#   'jesus',
#   'along',
#   'the',
#   'way',
#   'we',
#   'are',
#   'helping',
#   'to',
#   'slay',
#   'the',
#   'giants',
#   'that',
#   'arise',
#   'in',
#   'life'],
#  ['organized',
#   'to',
#   'promote',
#   'awareness',
#   'to',
#   'worth',
#   'while',
#   'charities',
#   'and',
#   'causes',
#   'by',
#   'organizing',
#   'events',
#   'for',
#   'their',
#   'benefit'],
#  ['connects',
#   'men',
#   'at',
#   'risk',
#   'to',
#   'comprehensive',
#   'healthcare',
#   'and',
#   'wellness',
#   'through',
#   'education',
#   'collaboration',
#   'and',
#   'advocacy',
#   'mhf',
#   's',
#   'vision',
#   'is',
#   'a',
#   'world',
#   'where',
#   'inequity',
#   'and',
#   'stigma',
#   'do',
#   'not',
#   'separate',
#   'men',
#   'from',
#   'healthcare'],
#  ['connects',
#   'men',
#   'at',
#   'risk',
#   'to',
#   'comprehensive',
#   'healthcare',
#   'and',
#   'wellness',
#   'through',
#   'education',
#   'partnerships',
#   'and',
#   'collaboration',
#   'inspiring',
#   'and',
#   'empowering',
#   'all',
#   'men',
#   'to',
#   'live',
#   'longer',
#   'healthier',
#   'and',
#   'happier',
#   'lives'],
#  ['connects',
#   'men',
#   'at',
#   'risk',
#   'to',
#   'comprehensive',
#   'healthcare',
#   'and',
#   'wellness',
#   'through',
#   'education',
#   'collaboration',
#   'and',
#   'advocacy',
#   'mhf',
#   's',
#   'vision',
#   'is',
#   'a',
#   'world',
#   'where',
#   'inequity',
#   'and',
#   'stigma',
#   'do',
#   'not',
#   'separate',
#   'men',
#   'from',
#   'healthcare'],
#  ['teching',
#   'dance',
#   'clasess',
#   'for',
#   'at',
#   'risk',
#   'inner',
#   'city',
#   'children'],
#  ['teaching',
#   'dance',
#   'clasess',
#   'to',
#   'at',
#   'risk',
#   'inner',
#   'city',
#   'children'],
#  ['teaching',
#   'dance',
#   'classes',
#   'to',
#   'inner',
#   'city',
#   'kids',
#   'in',
#   'jackson',
#   'to',
#   'keep',
#   'them',
#   'engaged',
#   'and',
#   'out',
#   'of',
#   'trouble'],
#  ['brothers',
#   'sisters',
#   'llcs',
#   'primary',
#   'mission',
#   'is',
#   'to',
#   'offer',
#   'training',
#   'co',
#   'ordinate',
#   'food',
#   'and',
#   'clothing',
#   'drives',
#   'offer',
#   'home',
#   'remodelling',
#   'provide',
#   'aid',
#   'and',
#   'charity',
#   'to',
#   'those',
#   'are',
#   'in',
#   'need',
#   'both',
#   'locally',
#   'and',
#   'globally',
#   'by',
#   'partnering',
#   'up',
#   'with',
#   'already',
#   'established',
#   'recognized',
#   'charities',
#   'doing',
#   'humanitarian',
#   'aid',
#   'internationally'],
#  ['brothers',
#   'sisters',
#   'llcs',
#   'primary',
#   'mission',
#   'is',
#   'to',
#   'offer',
#   'training',
#   'co',
#   'ordinate',
#   'food',
#   'and',
#   'clothing',
#   'drives',
#   'offer',
#   'home',
#   'remodelling',
#   'provide',
#   'aid',
#   'and',
#   'charity',
#   'to',
#   'those',
#   'are',
#   'in',
#   'need',
#   'both',
#   'locally',
#   'and',
#   'globally',
#   'by',
#   'partnering',
#   'up',
#   'with',
#   'already',
#   'established',
#   'recognized',
#   'charities',
#   'doing',
#   'humanitarian',
#   'aid',
#   'internationally'],
#  ['brothers',
#   'sisters',
#   'llcs',
#   'primary',
#   'mission',
#   'is',
#   'to',
#   'offer',
#   'training',
#   'co',
#   'ordinate',
#   'food',
#   'and',
#   'clothing',
#   'drives',
#   'offer',
#   'home',
#   'remodelling',
#   'provide',
#   'aid',
#   'and',
#   'charity',
#   'to',
#   'those',
#   'are',
#   'in',
#   'need',
#   'both',
#   'locally',
#   'and',
#   'globally',
#   'by',
#   'partnering',
#   'up',
#   'with',
#   'already',
#   'established',
#   'recognized',
#   'charities',
#   'doing',
#   'humanitarian',
#   'aid',
#   'internationally'],
#  ['to',
#   'help',
#   'needy',
#   'sick',
#   'disabled',
#   'members',
#   'of',
#   'the',
#   'israeli',
#   'jewish',
#   'community',
#   'with',
#   'their',
#   'financial',
#   'crisis'],
#  ['the',
#   'mission',
#   'of',
#   'the',
#   'wyoming',
#   'housing',
#   'partnership',
#   'inc',
#   'whp',
#   'is',
#   'to',
#   'create',
#   'and',
#   'maintain',
#   'affordable',
#   'housing',
#   'and',
#   'to',
#   'support',
#   'successful',
#   'homeownership',
#   'for',
#   'wyoming',
#   's',
#   'workforce'],
#  ['the',
#   'organization',
#   'provides',
#   'a',
#   'variety',
#   'of',
#   'programs',
#   'to',
#   'increase',
#   'child',
#   'and',
#   'parent',
#   'caregiver',
#   'community',
#   'based',
#   'early',
#   'learning',
#   'programs',
#   'for',
#   'children',
#   '0',
#   'to',
#   '5',
#   'and',
#   'their',
#   'families',
#   'the',
#   'three',
#   'programs',
#   'are',
#   'families',
#   'learning',
#   'in',
#   'play',
#   'flip',
#   'help',
#   'me',
#   'grow',
#   'playgroups',
#   'and',
#   'summer',
#   'camp'],
#  ['is', 'dedicated', 'to', 'the', 'process', 'of', 'restoring'],
#  ['is', 'dedicated', 'to', 'the', 'process', 'of', 'restoring'],
#  ['to',
#   'provide',
#   'scholarships',
#   'camperships',
#   'or',
#   'grants',
#   'to',
#   'lupis',
#   'patients',
#   'or',
#   'their',
#   'children'],
#  ['to',
#   'provide',
#   'scholarships',
#   'camperships',
#   'or',
#   'grants',
#   'to',
#   'lupis',
#   'patients',
#   'or',
#   'their',
#   'children'],
#  ['strengthening',
#   'children',
#   'and',
#   'their',
#   'families',
#   'by',
#   'partnering',
#   'with',
#   'foster',
#   'parents',
#   'and',
#   'the',
#   'community',
#   'to',
#   'promote',
#   'stability',
#   'strengthen',
#   'connections',
#   'and',
#   'encourage',
#   'lifelong',
#   'bonds'],
#  ['strengthening',
#   'children',
#   'and',
#   'their',
#   'families',
#   'by',
#   'partnering',
#   'with',
#   'foster',
#   'parents',
#   'and',
#   'the',
#   'community',
#   'to',
#   'promote',
#   'stability',
#   'strengthen',
#   'connections',
#   'and',
#   'encourage',
#   'lifelong',
#   'bonds'],
#  ['the',
#   'primary',
#   'purpose',
#   'of',
#   'the',
#   'organization',
#   'is',
#   'to',
#   'operate',
#   'a',
#   'christian',
#   'school',
#   'that',
#   'provides',
#   'a',
#   'distinctive',
#   'christian',
#   'educational',
#   'environment',
#   'that',
#   'graduates',
#   'students',
#   'who',
#   'demonstrate',
#   'godly',
#   'character',
#   'and',
#   'who',
#   'are',
#   'prepared',
#   'to',
#   'be',
#   'proficient',
#   'in',
#   'academics',
#   'and',
#   'life',
#   'skills'],
#  ['the',
#   'primary',
#   'purpose',
#   'of',
#   'the',
#   'organization',
#   'is',
#   'to',
#   'operate',
#   'a',
#   'christian',
#   'school',
#   'that',
#   'provides',
#   'a',
#   'distinctive',
#   'christian',
#   'educational',
#   'environment',
#   'that',
#   'graduates',
#   'students',
#   'who',
#   'demonstrate',
#   'godly',
#   'character',
#   'and',
#   'who',
#   'are',
#   'prepared',
#   'to',
#   'be',
#   'proficient',
#   'in',
#   'academics',
#   'and',
#   'life',
#   'skills'],
#  ['treating',
#   'shelter',
#   'animals',
#   'that',
#   'are',
#   'at',
#   'risk',
#   'of',
#   'being',
#   'euthanized',
#   'due',
#   'to',
#   'medical'],
#  ['treating', 'shelter', 'animals', 'that', 'are', 'at'],
#  ['none'],
#  ['teaching', 'christian', 'doctrine'],
#  ['to',
#   'create',
#   'an',
#   'evidence',
#   'based',
#   'consumer',
#   'and',
#   'family',
#   'driven',
#   'recovery',
#   'oriented',
#   'behavioral',
#   'health',
#   'system',
#   'care',
#   'and',
#   'center',
#   'of',
#   'excellence',
#   'for',
#   'individuals',
#   'confronted',
#   'with',
#   'mental',
#   'health',
#   'and',
#   'or',
#   'substance',
#   'abuse',
#   'issues'],
#  ['to',
#   'create',
#   'an',
#   'evidence',
#   'based',
#   'consumer',
#   'and',
#   'family',
#   'driven',
#   'recovery',
#   'oriented',
#   'behavioral',
#   'health',
#   'system',
#   'care',
#   'and',
#   'center',
#   'of',
#   'excellence',
#   'for',
#   'individuals',
#   'confronted',
#   'with',
#   'mental',
#   'health',
#   'and',
#   'or',
#   'substance',
#   'abuse',
#   'issues'],
#  ['to',
#   'be',
#   'a',
#   'light',
#   'for',
#   'families',
#   'enduring',
#   'the',
#   'storm',
#   'of',
#   'cancer',
#   'by',
#   'building',
#   'faith',
#   'fostering',
#   'hope',
#   'and',
#   'loving',
#   'deeply'],
#  ['established',
#   'to',
#   'promote',
#   'the',
#   'arts',
#   'by',
#   'helping',
#   'visual',
#   'artists',
#   'through',
#   'grant',
#   'making',
#   'to',
#   'individual',
#   'artists',
#   'for',
#   'specific',
#   'projects',
#   'workshops',
#   'and',
#   'webinars',
#   'on',
#   'topics',
#   'relevant',
#   'to',
#   'the',
#   'arts',
#   'and',
#   'artists',
#   'and',
#   'serving',
#   'as',
#   'a',
#   'clearinghouse',
#   'for',
#   'community',
#   'interactions',
#   'and',
#   'mentorship'],
#  ['to',
#   'further',
#   'the',
#   'educational',
#   'purposes',
#   'of',
#   'the',
#   'public',
#   'library',
#   'of',
#   'the',
#   'city',
#   'of',
#   'brentwood',
#   'this',
#   'will',
#   'include',
#   'the',
#   'raising',
#   'of',
#   'funds',
#   'toward',
#   'the',
#   'replacement',
#   'of',
#   'the',
#   'library',
#   'building',
#   'and',
#   'ongoing',
#   'supporrt',
#   'of',
#   'the',
#   'programs',
#   'of',
#   'the',
#   'library'],
#  ['to',
#   'provide',
#   'opportunities',
#   'for',
#   'children',
#   'and',
#   'youth',
#   'to',
#   'participate',
#   'in',
#   'recreational',
#   'cultural',
#   'social',
#   'and',
#   'civic',
#   'activities',
#   'through',
#   'membership',
#   'in',
#   'clubs',
#   'and',
#   'other',
#   'youth',
#   'groups',
#   'with',
#   'a',
#   'special',
#   'focus',
#   'whose',
#   'purpose',
#   'is',
#   'to',
#   'help',
#   'youngsters',
#   'develop',
#   'their',
#   'potential',
#   'and',
#   'grow',
#   'into',
#   'healthy',
#   'educated',
#   'responsible',
#   'and',
#   'productive',
#   'adults'],
#  ['to',
#   'provide',
#   'opportunities',
#   'for',
#   'children',
#   'and',
#   'youth',
#   'to',
#   'participate',
#   'in',
#   'recreational',
#   'cultural',
#   'social',
#   'and',
#   'civic',
#   'activities',
#   'through',
#   'membership',
#   'in',
#   'clubs',
#   'and',
#   'other',
#   'youth',
#   'groups',
#   'with',
#   'a',
#   'special',
#   'focus',
#   'whose',
#   'purpose',
#   'is',
#   'to',
#   'help',
#   'youngsters',
#   'develop',
#   'their',
#   'potential',
#   'and',
#   'grow',
#   'into',
#   'healthy',
#   'educated',
#   'responsible',
#   'and',
#   'productive',
#   'adults'],
#  ['to',
#   'provide',
#   'opportunities',
#   'for',
#   'children',
#   'and',
#   'youth',
#   'to',
#   'participate',
#   'in',
#   'recreational',
#   'cultural',
#   'social',
#   'and',
#   'civic',
#   'activities',
#   'through',
#   'membership',
#   'in',
#   'clubs',
#   'and',
#   'other',
#   'youth',
#   'groups',
#   'with',
#   'a',
#   'special',
#   'focus',
#   'whose',
#   'purpose',
#   'is',
#   'to',
#   'help',
#   'youngsters',
#   'develop',
#   'their',
#   'potential',
#   'and',
#   'grow',
#   'into',
#   'healthy',
#   'educated',
#   'responsible',
#   'and',
#   'productive',
#   'adults'],
#  ['the',
#   'bee',
#   'foundation',
#   'is',
#   'dedicated',
#   'to',
#   'raising',
#   'awareness',
#   'of',
#   'brain',
#   'aneurysms',
#   'and',
#   'funding',
#   'for',
#   'innovative',
#   'research',
#   'that',
#   'saves',
#   'lives'],
#  ...]

# %%
from gensim.models import Word2Vec

model = Word2Vec(words_from_df, size=100, window=5, min_count=1, workers=4)

vectors = model.wv

len(model.wv.vocab)
# Out:
# 6533

# %%
vectors['education']

vectors.most_similar('soccer')
# Out:
# [('based', 0.999845027923584),
#  ('arts', 0.9998424053192139),
#  ('club', 0.999841570854187),
#  ('its', 0.9998363256454468),
#  ('maintain', 0.9998341798782349),
#  ('county', 0.9998312592506409),
#  ('schools', 0.9998174905776978),
#  ('sports', 0.9998170733451843),
#  ('art', 0.9998161196708679),
#  ('society', 0.999815821647644)]
